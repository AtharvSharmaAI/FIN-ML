# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
train_data = pd.read_csv('../mitsui-commodity-prediction-challenge/train.csv')
test_data = pd.read_csv('../mitsui-commodity-prediction-challenge/test.csv')
pairs = pd.read_csv('../mitsui-commodity-prediction-challenge/target_pairs.csv')
labels = pd.read_csv('../mitsui-commodity-prediction-challenge/train_labels.csv')

# %%
train_data
# Out:
#       date_id  LME_AH_Close  LME_CA_Close  LME_PB_Close  LME_ZS_Close  \
# 0           0        2264.5        7205.0        2570.0        3349.0
# 1           1        2228.0        7147.0        2579.0        3327.0
# 2           2        2250.0        7188.5        2587.0        3362.0
# 3           3        2202.5        7121.0        2540.0        3354.0
# 4           4        2175.0        7125.0        2604.0        3386.0
# ...       ...           ...           ...           ...           ...
# 1912     1912        2450.0        9523.5        1961.5        2676.5
# 1913     1913        2471.5        9519.5        1980.5        2710.5
# 1914     1914        2471.5        9533.5        1974.0        2693.0
# 1915     1915        2456.0        9500.5        1970.0        2697.5
# 1916     1916        2463.5        9610.0        1991.0        2701.5
#
#       JPX_Gold_Mini_Futures_Open  JPX_Gold_Rolling-Spot_Futures_Open  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                         4684.0                              4691.0
# 3                         4728.0                              4737.0
# 4                            NaN                                 NaN
# ...                          ...                                 ...
# 1912                     15086.0                             15440.0
# 1913                     15165.0                             15509.0
# 1914                     15040.0                             15477.0
# 1915                     15420.0                             15752.0
# 1916                     15416.0                             15802.0
#
#       JPX_Gold_Standard_Futures_Open  JPX_Platinum_Mini_Futures_Open  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                             4684.0                          3363.0
# 3                             4729.0                          3430.0
# 4                                NaN                             NaN
# ...                              ...                             ...
# 1912                         15085.0                          4461.5
# 1913                         15162.0                          4495.0
# 1914                         15044.0                          4544.5
# 1915                         15420.0                          4670.0
# 1916                         15415.0                          4730.5
#
#       JPX_Platinum_Standard_Futures_Open  ...  FX_GBPCAD  FX_CADCHF  \
# 0                                    NaN  ...   1.699987   0.776874
# 1                                    NaN  ...   1.695279   0.778682
# 2                                 3367.0  ...   1.692724   0.780186
# 3                                 3426.0  ...   1.683111   0.785329
# 4                                    NaN  ...   1.684816   0.787264
# ...                                  ...  ...        ...        ...
# 1912                              4467.0  ...   1.864661   0.598318
# 1913                              4490.0  ...   1.863539   0.594400
# 1914                              4555.0  ...   1.860067   0.595250
# 1915                              4685.0  ...   1.859624   0.597780
# 1916                              4751.0  ...   1.860472   0.597644
#
#       FX_NZDCAD  FX_NZDCHF  FX_ZAREUR  FX_NOKGBP  FX_NOKCHF  FX_ZARCHF  \
# 0      0.888115   0.689954   0.066653   0.090582   0.119630   0.078135
# 1      0.889488   0.692628   0.067354   0.091297   0.120520   0.079066
# 2      0.894004   0.697490   0.067394   0.091478   0.120809   0.079287
# 3      0.889439   0.698502   0.067639   0.091558   0.121021   0.079285
# 4      0.891042   0.701485   0.067443   0.091266   0.121055   0.078925
# ...         ...        ...        ...        ...        ...        ...
# 1912   0.827529   0.495125   0.049224   0.072574   0.080968   0.046175
# 1913   0.824390   0.490018   0.049409   0.072828   0.080671   0.046113
# 1914   0.822392   0.489529   0.049095   0.073232   0.081083   0.045901
# 1915   0.817224   0.488520   0.049205   0.073018   0.081170   0.045987
# 1916   0.822219   0.491394   0.049321   0.073058   0.081233   0.046037
#
#       FX_NOKJPY  FX_ZARGBP
# 0     13.822740   0.059163
# 1     13.888146   0.059895
# 2     13.983675   0.060037
# 3     14.035571   0.059983
# 4     14.013760   0.059503
# ...         ...        ...
# 1912  14.058107   0.041388
# 1913  14.082236   0.041630
# 1914  14.126606   0.041457
# 1915  14.095322   0.041368
# 1916  14.107311   0.041404
#
# [1917 rows x 558 columns]

# %%
train_names = list(train_data.columns)

train_names = [name.replace("open_interest", "open interest")
                    .replace("settlement_price", "settlement price")
                    .replace("US_Stock", "US Stock")
                    .replace("adj_", "adjusted ")
               for name in train_names]

train_names = [re.split("_", name) for name in train_names]

# %%
for col in train_names:
    print(col)
# Out:
# ['date', 'id']
# ['LME', 'AH', 'Close']
# ['LME', 'CA', 'Close']
# ['LME', 'PB', 'Close']
# ['LME', 'ZS', 'Close']
# ['JPX', 'Gold', 'Mini', 'Futures', 'Open']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'Open']
# ['JPX', 'Gold', 'Standard', 'Futures', 'Open']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'Open']
# ['JPX', 'Platinum', 'Standard', 'Futures', 'Open']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'Open']
# ['JPX', 'Gold', 'Mini', 'Futures', 'High']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'High']
# ['JPX', 'Gold', 'Standard', 'Futures', 'High']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'High']
# ['JPX', 'Platinum', 'Standard', 'Futures', 'High']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'High']
# ['JPX', 'Gold', 'Mini', 'Futures', 'Low']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'Low']
# ['JPX', 'Gold', 'Standard', 'Futures', 'Low']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'Low']
# ['JPX', 'Platinum', 'Standard', 'Futures', 'Low']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'Low']
# ['JPX', 'Gold', 'Mini', 'Futures', 'Close']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'Close']
# ['JPX', 'Gold', 'Standard', 'Futures', 'Close']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'Close']
# ['JPX', 'Platinum', 'Standard', 'Futures', 'Close']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'Close']
# ['JPX', 'Gold', 'Mini', 'Futures', 'Volume']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'Volume']
# ['JPX', 'Gold', 'Standard', 'Futures', 'Volume']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'Volume']
# ['JPX', 'Platinum', 'Standard', 'Futures', 'Volume']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'Volume']
# ['JPX', 'Gold', 'Mini', 'Futures', 'settlement price']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'settlement price']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'settlement price']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'settlement price']
# ['JPX', 'Gold', 'Mini', 'Futures', 'open interest']
# ['JPX', 'Gold', 'Rolling-Spot', 'Futures', 'open interest']
# ['JPX', 'Gold', 'Standard', 'Futures', 'open interest']
# ['JPX', 'Platinum', 'Mini', 'Futures', 'open interest']
# ['JPX', 'Platinum', 'Standard', 'Futures', 'open interest']
# ['JPX', 'RSS3', 'Rubber', 'Futures', 'open interest']
# ['US Stock', 'ACWI', 'adjusted open']
# ['US Stock', 'AEM', 'adjusted open']
# ['US Stock', 'AG', 'adjusted open']
# ['US Stock', 'AGG', 'adjusted open']
# ['US Stock', 'ALB', 'adjusted open']
# ['US Stock', 'AMP', 'adjusted open']
# ['US Stock', 'BCS', 'adjusted open']
# ['US Stock', 'BKR', 'adjusted open']
# ['US Stock', 'BND', 'adjusted open']
# ['US Stock', 'BNDX', 'adjusted open']
# ['US Stock', 'BP', 'adjusted open']
# ['US Stock', 'BSV', 'adjusted open']
# ['US Stock', 'CAT', 'adjusted open']
# ['US Stock', 'CCJ', 'adjusted open']
# ['US Stock', 'CLF', 'adjusted open']
# ['US Stock', 'COP', 'adjusted open']
# ['US Stock', 'CVE', 'adjusted open']
# ['US Stock', 'CVX', 'adjusted open']
# ['US Stock', 'DE', 'adjusted open']
# ['US Stock', 'DVN', 'adjusted open']
# ['US Stock', 'EEM', 'adjusted open']
# ['US Stock', 'EFA', 'adjusted open']
# ['US Stock', 'EMB', 'adjusted open']
# ['US Stock', 'ENB', 'adjusted open']
# ['US Stock', 'EOG', 'adjusted open']
# ['US Stock', 'EWJ', 'adjusted open']
# ['US Stock', 'EWT', 'adjusted open']
# ['US Stock', 'EWY', 'adjusted open']
# ['US Stock', 'EWZ', 'adjusted open']
# ['US Stock', 'FCX', 'adjusted open']
# ['US Stock', 'FNV', 'adjusted open']
# ['US Stock', 'FXI', 'adjusted open']
# ['US Stock', 'GDX', 'adjusted open']
# ['US Stock', 'GDXJ', 'adjusted open']
# ['US Stock', 'GLD', 'adjusted open']
# ['US Stock', 'GOLD', 'adjusted open']
# ['US Stock', 'HAL', 'adjusted open']
# ['US Stock', 'HES', 'adjusted open']
# ['US Stock', 'HL', 'adjusted open']
# ['US Stock', 'IAU', 'adjusted open']
# ['US Stock', 'IEF', 'adjusted open']
# ['US Stock', 'IEMG', 'adjusted open']
# ['US Stock', 'IGSB', 'adjusted open']
# ['US Stock', 'JNK', 'adjusted open']
# ['US Stock', 'KGC', 'adjusted open']
# ['US Stock', 'KMI', 'adjusted open']
# ['US Stock', 'LQD', 'adjusted open']
# ['US Stock', 'LYB', 'adjusted open']
# ['US Stock', 'MBB', 'adjusted open']
# ['US Stock', 'MPC', 'adjusted open']
# ['US Stock', 'MS', 'adjusted open']
# ['US Stock', 'NEM', 'adjusted open']
# ['US Stock', 'NUE', 'adjusted open']
# ['US Stock', 'NUGT', 'adjusted open']
# ['US Stock', 'OIH', 'adjusted open']
# ['US Stock', 'OKE', 'adjusted open']
# ['US Stock', 'OXY', 'adjusted open']
# ['US Stock', 'PAAS', 'adjusted open']
# ['US Stock', 'RIO', 'adjusted open']
# ['US Stock', 'RSP', 'adjusted open']
# ['US Stock', 'RY', 'adjusted open']
# ['US Stock', 'SCCO', 'adjusted open']
# ['US Stock', 'SHEL', 'adjusted open']
# ['US Stock', 'SHY', 'adjusted open']
# ['US Stock', 'SLB', 'adjusted open']
# ['US Stock', 'SLV', 'adjusted open']
# ['US Stock', 'SPIB', 'adjusted open']
# ['US Stock', 'SPTL', 'adjusted open']
# ['US Stock', 'SPYV', 'adjusted open']
# ['US Stock', 'STLD', 'adjusted open']
# ['US Stock', 'TD', 'adjusted open']
# ['US Stock', 'TECK', 'adjusted open']
# ['US Stock', 'TIP', 'adjusted open']
# ['US Stock', 'TRGP', 'adjusted open']
# ['US Stock', 'URA', 'adjusted open']
# ['US Stock', 'VALE', 'adjusted open']
# ['US Stock', 'VCIT', 'adjusted open']
# ['US Stock', 'VCSH', 'adjusted open']
# ['US Stock', 'VEA', 'adjusted open']
# ['US Stock', 'VGIT', 'adjusted open']
# ['US Stock', 'VGK', 'adjusted open']
# ['US Stock', 'VGLT', 'adjusted open']
# ['US Stock', 'VGSH', 'adjusted open']
# ['US Stock', 'VT', 'adjusted open']
# ['US Stock', 'VTV', 'adjusted open']
# ['US Stock', 'VWO', 'adjusted open']
# ['US Stock', 'VXUS', 'adjusted open']
# ['US Stock', 'VYM', 'adjusted open']
# ['US Stock', 'WMB', 'adjusted open']
# ['US Stock', 'WPM', 'adjusted open']
# ['US Stock', 'X', 'adjusted open']
# ['US Stock', 'XLB', 'adjusted open']
# ['US Stock', 'XLE', 'adjusted open']
# ['US Stock', 'XOM', 'adjusted open']
# ['US Stock', 'YINN', 'adjusted open']
# ['US Stock', 'ACWI', 'adjusted high']
# ['US Stock', 'AEM', 'adjusted high']
# ['US Stock', 'AG', 'adjusted high']
# ['US Stock', 'AGG', 'adjusted high']
# ['US Stock', 'ALB', 'adjusted high']
# ['US Stock', 'AMP', 'adjusted high']
# ['US Stock', 'BCS', 'adjusted high']
# ['US Stock', 'BKR', 'adjusted high']
# ['US Stock', 'BND', 'adjusted high']
# ['US Stock', 'BNDX', 'adjusted high']
# ['US Stock', 'BP', 'adjusted high']
# ['US Stock', 'BSV', 'adjusted high']
# ['US Stock', 'CAT', 'adjusted high']
# ['US Stock', 'CCJ', 'adjusted high']
# ['US Stock', 'CLF', 'adjusted high']
# ['US Stock', 'COP', 'adjusted high']
# ['US Stock', 'CVE', 'adjusted high']
# ['US Stock', 'CVX', 'adjusted high']
# ['US Stock', 'DE', 'adjusted high']
# ['US Stock', 'DVN', 'adjusted high']
# ['US Stock', 'EEM', 'adjusted high']
# ['US Stock', 'EFA', 'adjusted high']
# ['US Stock', 'EMB', 'adjusted high']
# ['US Stock', 'ENB', 'adjusted high']
# ['US Stock', 'EOG', 'adjusted high']
# ['US Stock', 'EWJ', 'adjusted high']
# ['US Stock', 'EWT', 'adjusted high']
# ['US Stock', 'EWY', 'adjusted high']
# ['US Stock', 'EWZ', 'adjusted high']
# ['US Stock', 'FCX', 'adjusted high']
# ['US Stock', 'FNV', 'adjusted high']
# ['US Stock', 'FXI', 'adjusted high']
# ['US Stock', 'GDX', 'adjusted high']
# ['US Stock', 'GDXJ', 'adjusted high']
# ['US Stock', 'GLD', 'adjusted high']
# ['US Stock', 'GOLD', 'adjusted high']
# ['US Stock', 'HAL', 'adjusted high']
# ['US Stock', 'HES', 'adjusted high']
# ['US Stock', 'HL', 'adjusted high']
# ['US Stock', 'IAU', 'adjusted high']
# ['US Stock', 'IEF', 'adjusted high']
# ['US Stock', 'IEMG', 'adjusted high']
# ['US Stock', 'IGSB', 'adjusted high']
# ['US Stock', 'JNK', 'adjusted high']
# ['US Stock', 'KGC', 'adjusted high']
# ['US Stock', 'KMI', 'adjusted high']
# ['US Stock', 'LQD', 'adjusted high']
# ['US Stock', 'LYB', 'adjusted high']
# ['US Stock', 'MBB', 'adjusted high']
# ['US Stock', 'MPC', 'adjusted high']
# ['US Stock', 'MS', 'adjusted high']
# ['US Stock', 'NEM', 'adjusted high']
# ['US Stock', 'NUE', 'adjusted high']
# ['US Stock', 'NUGT', 'adjusted high']
# ['US Stock', 'OIH', 'adjusted high']
# ['US Stock', 'OKE', 'adjusted high']
# ['US Stock', 'OXY', 'adjusted high']
# ['US Stock', 'PAAS', 'adjusted high']
# ['US Stock', 'RIO', 'adjusted high']
# ['US Stock', 'RSP', 'adjusted high']
# ['US Stock', 'RY', 'adjusted high']
# ['US Stock', 'SCCO', 'adjusted high']
# ['US Stock', 'SHEL', 'adjusted high']
# ['US Stock', 'SHY', 'adjusted high']
# ['US Stock', 'SLB', 'adjusted high']
# ['US Stock', 'SLV', 'adjusted high']
# ['US Stock', 'SPIB', 'adjusted high']
# ['US Stock', 'SPTL', 'adjusted high']
# ['US Stock', 'SPYV', 'adjusted high']
# ['US Stock', 'STLD', 'adjusted high']
# ['US Stock', 'TD', 'adjusted high']
# ['US Stock', 'TECK', 'adjusted high']
# ['US Stock', 'TIP', 'adjusted high']
# ['US Stock', 'TRGP', 'adjusted high']
# ['US Stock', 'URA', 'adjusted high']
# ['US Stock', 'VALE', 'adjusted high']
# ['US Stock', 'VCIT', 'adjusted high']
# ['US Stock', 'VCSH', 'adjusted high']
# ['US Stock', 'VEA', 'adjusted high']
# ['US Stock', 'VGIT', 'adjusted high']
# ['US Stock', 'VGK', 'adjusted high']
# ['US Stock', 'VGLT', 'adjusted high']
# ['US Stock', 'VGSH', 'adjusted high']
# ['US Stock', 'VT', 'adjusted high']
# ['US Stock', 'VTV', 'adjusted high']
# ['US Stock', 'VWO', 'adjusted high']
# ['US Stock', 'VXUS', 'adjusted high']
# ['US Stock', 'VYM', 'adjusted high']
# ['US Stock', 'WMB', 'adjusted high']
# ['US Stock', 'WPM', 'adjusted high']
# ['US Stock', 'X', 'adjusted high']
# ['US Stock', 'XLB', 'adjusted high']
# ['US Stock', 'XLE', 'adjusted high']
# ['US Stock', 'XOM', 'adjusted high']
# ['US Stock', 'YINN', 'adjusted high']
# ['US Stock', 'ACWI', 'adjusted low']
# ['US Stock', 'AEM', 'adjusted low']
# ['US Stock', 'AG', 'adjusted low']
# ['US Stock', 'AGG', 'adjusted low']
# ['US Stock', 'ALB', 'adjusted low']
# ['US Stock', 'AMP', 'adjusted low']
# ['US Stock', 'BCS', 'adjusted low']
# ['US Stock', 'BKR', 'adjusted low']
# ['US Stock', 'BND', 'adjusted low']
# ['US Stock', 'BNDX', 'adjusted low']
# ['US Stock', 'BP', 'adjusted low']
# ['US Stock', 'BSV', 'adjusted low']
# ['US Stock', 'CAT', 'adjusted low']
# ['US Stock', 'CCJ', 'adjusted low']
# ['US Stock', 'CLF', 'adjusted low']
# ['US Stock', 'COP', 'adjusted low']
# ['US Stock', 'CVE', 'adjusted low']
# ['US Stock', 'CVX', 'adjusted low']
# ['US Stock', 'DE', 'adjusted low']
# ['US Stock', 'DVN', 'adjusted low']
# ['US Stock', 'EEM', 'adjusted low']
# ['US Stock', 'EFA', 'adjusted low']
# ['US Stock', 'EMB', 'adjusted low']
# ['US Stock', 'ENB', 'adjusted low']
# ['US Stock', 'EOG', 'adjusted low']
# ['US Stock', 'EWJ', 'adjusted low']
# ['US Stock', 'EWT', 'adjusted low']
# ['US Stock', 'EWY', 'adjusted low']
# ['US Stock', 'EWZ', 'adjusted low']
# ['US Stock', 'FCX', 'adjusted low']
# ['US Stock', 'FNV', 'adjusted low']
# ['US Stock', 'FXI', 'adjusted low']
# ['US Stock', 'GDX', 'adjusted low']
# ['US Stock', 'GDXJ', 'adjusted low']
# ['US Stock', 'GLD', 'adjusted low']
# ['US Stock', 'GOLD', 'adjusted low']
# ['US Stock', 'HAL', 'adjusted low']
# ['US Stock', 'HES', 'adjusted low']
# ['US Stock', 'HL', 'adjusted low']
# ['US Stock', 'IAU', 'adjusted low']
# ['US Stock', 'IEF', 'adjusted low']
# ['US Stock', 'IEMG', 'adjusted low']
# ['US Stock', 'IGSB', 'adjusted low']
# ['US Stock', 'JNK', 'adjusted low']
# ['US Stock', 'KGC', 'adjusted low']
# ['US Stock', 'KMI', 'adjusted low']
# ['US Stock', 'LQD', 'adjusted low']
# ['US Stock', 'LYB', 'adjusted low']
# ['US Stock', 'MBB', 'adjusted low']
# ['US Stock', 'MPC', 'adjusted low']
# ['US Stock', 'MS', 'adjusted low']
# ['US Stock', 'NEM', 'adjusted low']
# ['US Stock', 'NUE', 'adjusted low']
# ['US Stock', 'NUGT', 'adjusted low']
# ['US Stock', 'OIH', 'adjusted low']
# ['US Stock', 'OKE', 'adjusted low']
# ['US Stock', 'OXY', 'adjusted low']
# ['US Stock', 'PAAS', 'adjusted low']
# ['US Stock', 'RIO', 'adjusted low']
# ['US Stock', 'RSP', 'adjusted low']
# ['US Stock', 'RY', 'adjusted low']
# ['US Stock', 'SCCO', 'adjusted low']
# ['US Stock', 'SHEL', 'adjusted low']
# ['US Stock', 'SHY', 'adjusted low']
# ['US Stock', 'SLB', 'adjusted low']
# ['US Stock', 'SLV', 'adjusted low']
# ['US Stock', 'SPIB', 'adjusted low']
# ['US Stock', 'SPTL', 'adjusted low']
# ['US Stock', 'SPYV', 'adjusted low']
# ['US Stock', 'STLD', 'adjusted low']
# ['US Stock', 'TD', 'adjusted low']
# ['US Stock', 'TECK', 'adjusted low']
# ['US Stock', 'TIP', 'adjusted low']
# ['US Stock', 'TRGP', 'adjusted low']
# ['US Stock', 'URA', 'adjusted low']
# ['US Stock', 'VALE', 'adjusted low']
# ['US Stock', 'VCIT', 'adjusted low']
# ['US Stock', 'VCSH', 'adjusted low']
# ['US Stock', 'VEA', 'adjusted low']
# ['US Stock', 'VGIT', 'adjusted low']
# ['US Stock', 'VGK', 'adjusted low']
# ['US Stock', 'VGLT', 'adjusted low']
# ['US Stock', 'VGSH', 'adjusted low']
# ['US Stock', 'VT', 'adjusted low']
# ['US Stock', 'VTV', 'adjusted low']
# ['US Stock', 'VWO', 'adjusted low']
# ['US Stock', 'VXUS', 'adjusted low']
# ['US Stock', 'VYM', 'adjusted low']
# ['US Stock', 'WMB', 'adjusted low']
# ['US Stock', 'WPM', 'adjusted low']
# ['US Stock', 'X', 'adjusted low']
# ['US Stock', 'XLB', 'adjusted low']
# ['US Stock', 'XLE', 'adjusted low']
# ['US Stock', 'XOM', 'adjusted low']
# ['US Stock', 'YINN', 'adjusted low']
# ['US Stock', 'ACWI', 'adjusted close']
# ['US Stock', 'AEM', 'adjusted close']
# ['US Stock', 'AG', 'adjusted close']
# ['US Stock', 'AGG', 'adjusted close']
# ['US Stock', 'ALB', 'adjusted close']
# ['US Stock', 'AMP', 'adjusted close']
# ['US Stock', 'BCS', 'adjusted close']
# ['US Stock', 'BKR', 'adjusted close']
# ['US Stock', 'BND', 'adjusted close']
# ['US Stock', 'BNDX', 'adjusted close']
# ['US Stock', 'BP', 'adjusted close']
# ['US Stock', 'BSV', 'adjusted close']
# ['US Stock', 'CAT', 'adjusted close']
# ['US Stock', 'CCJ', 'adjusted close']
# ['US Stock', 'CLF', 'adjusted close']
# ['US Stock', 'COP', 'adjusted close']
# ['US Stock', 'CVE', 'adjusted close']
# ['US Stock', 'CVX', 'adjusted close']
# ['US Stock', 'DE', 'adjusted close']
# ['US Stock', 'DVN', 'adjusted close']
# ['US Stock', 'EEM', 'adjusted close']
# ['US Stock', 'EFA', 'adjusted close']
# ['US Stock', 'EMB', 'adjusted close']
# ['US Stock', 'ENB', 'adjusted close']
# ['US Stock', 'EOG', 'adjusted close']
# ['US Stock', 'EWJ', 'adjusted close']
# ['US Stock', 'EWT', 'adjusted close']
# ['US Stock', 'EWY', 'adjusted close']
# ['US Stock', 'EWZ', 'adjusted close']
# ['US Stock', 'FCX', 'adjusted close']
# ['US Stock', 'FNV', 'adjusted close']
# ['US Stock', 'FXI', 'adjusted close']
# ['US Stock', 'GDX', 'adjusted close']
# ['US Stock', 'GDXJ', 'adjusted close']
# ['US Stock', 'GLD', 'adjusted close']
# ['US Stock', 'GOLD', 'adjusted close']
# ['US Stock', 'HAL', 'adjusted close']
# ['US Stock', 'HES', 'adjusted close']
# ['US Stock', 'HL', 'adjusted close']
# ['US Stock', 'IAU', 'adjusted close']
# ['US Stock', 'IEF', 'adjusted close']
# ['US Stock', 'IEMG', 'adjusted close']
# ['US Stock', 'IGSB', 'adjusted close']
# ['US Stock', 'JNK', 'adjusted close']
# ['US Stock', 'KGC', 'adjusted close']
# ['US Stock', 'KMI', 'adjusted close']
# ['US Stock', 'LQD', 'adjusted close']
# ['US Stock', 'LYB', 'adjusted close']
# ['US Stock', 'MBB', 'adjusted close']
# ['US Stock', 'MPC', 'adjusted close']
# ['US Stock', 'MS', 'adjusted close']
# ['US Stock', 'NEM', 'adjusted close']
# ['US Stock', 'NUE', 'adjusted close']
# ['US Stock', 'NUGT', 'adjusted close']
# ['US Stock', 'OIH', 'adjusted close']
# ['US Stock', 'OKE', 'adjusted close']
# ['US Stock', 'OXY', 'adjusted close']
# ['US Stock', 'PAAS', 'adjusted close']
# ['US Stock', 'RIO', 'adjusted close']
# ['US Stock', 'RSP', 'adjusted close']
# ['US Stock', 'RY', 'adjusted close']
# ['US Stock', 'SCCO', 'adjusted close']
# ['US Stock', 'SHEL', 'adjusted close']
# ['US Stock', 'SHY', 'adjusted close']
# ['US Stock', 'SLB', 'adjusted close']
# ['US Stock', 'SLV', 'adjusted close']
# ['US Stock', 'SPIB', 'adjusted close']
# ['US Stock', 'SPTL', 'adjusted close']
# ['US Stock', 'SPYV', 'adjusted close']
# ['US Stock', 'STLD', 'adjusted close']
# ['US Stock', 'TD', 'adjusted close']
# ['US Stock', 'TECK', 'adjusted close']
# ['US Stock', 'TIP', 'adjusted close']
# ['US Stock', 'TRGP', 'adjusted close']
# ['US Stock', 'URA', 'adjusted close']
# ['US Stock', 'VALE', 'adjusted close']
# ['US Stock', 'VCIT', 'adjusted close']
# ['US Stock', 'VCSH', 'adjusted close']
# ['US Stock', 'VEA', 'adjusted close']
# ['US Stock', 'VGIT', 'adjusted close']
# ['US Stock', 'VGK', 'adjusted close']
# ['US Stock', 'VGLT', 'adjusted close']
# ['US Stock', 'VGSH', 'adjusted close']
# ['US Stock', 'VT', 'adjusted close']
# ['US Stock', 'VTV', 'adjusted close']
# ['US Stock', 'VWO', 'adjusted close']
# ['US Stock', 'VXUS', 'adjusted close']
# ['US Stock', 'VYM', 'adjusted close']
# ['US Stock', 'WMB', 'adjusted close']
# ['US Stock', 'WPM', 'adjusted close']
# ['US Stock', 'X', 'adjusted close']
# ['US Stock', 'XLB', 'adjusted close']
# ['US Stock', 'XLE', 'adjusted close']
# ['US Stock', 'XOM', 'adjusted close']
# ['US Stock', 'YINN', 'adjusted close']
# ['US Stock', 'ACWI', 'adjusted volume']
# ['US Stock', 'AEM', 'adjusted volume']
# ['US Stock', 'AG', 'adjusted volume']
# ['US Stock', 'AGG', 'adjusted volume']
# ['US Stock', 'ALB', 'adjusted volume']
# ['US Stock', 'AMP', 'adjusted volume']
# ['US Stock', 'BCS', 'adjusted volume']
# ['US Stock', 'BKR', 'adjusted volume']
# ['US Stock', 'BND', 'adjusted volume']
# ['US Stock', 'BNDX', 'adjusted volume']
# ['US Stock', 'BP', 'adjusted volume']
# ['US Stock', 'BSV', 'adjusted volume']
# ['US Stock', 'CAT', 'adjusted volume']
# ['US Stock', 'CCJ', 'adjusted volume']
# ['US Stock', 'CLF', 'adjusted volume']
# ['US Stock', 'COP', 'adjusted volume']
# ['US Stock', 'CVE', 'adjusted volume']
# ['US Stock', 'CVX', 'adjusted volume']
# ['US Stock', 'DE', 'adjusted volume']
# ['US Stock', 'DVN', 'adjusted volume']
# ['US Stock', 'EEM', 'adjusted volume']
# ['US Stock', 'EFA', 'adjusted volume']
# ['US Stock', 'EMB', 'adjusted volume']
# ['US Stock', 'ENB', 'adjusted volume']
# ['US Stock', 'EOG', 'adjusted volume']
# ['US Stock', 'EWJ', 'adjusted volume']
# ['US Stock', 'EWT', 'adjusted volume']
# ['US Stock', 'EWY', 'adjusted volume']
# ['US Stock', 'EWZ', 'adjusted volume']
# ['US Stock', 'FCX', 'adjusted volume']
# ['US Stock', 'FNV', 'adjusted volume']
# ['US Stock', 'FXI', 'adjusted volume']
# ['US Stock', 'GDX', 'adjusted volume']
# ['US Stock', 'GDXJ', 'adjusted volume']
# ['US Stock', 'GLD', 'adjusted volume']
# ['US Stock', 'GOLD', 'adjusted volume']
# ['US Stock', 'HAL', 'adjusted volume']
# ['US Stock', 'HES', 'adjusted volume']
# ['US Stock', 'HL', 'adjusted volume']
# ['US Stock', 'IAU', 'adjusted volume']
# ['US Stock', 'IEF', 'adjusted volume']
# ['US Stock', 'IEMG', 'adjusted volume']
# ['US Stock', 'IGSB', 'adjusted volume']
# ['US Stock', 'JNK', 'adjusted volume']
# ['US Stock', 'KGC', 'adjusted volume']
# ['US Stock', 'KMI', 'adjusted volume']
# ['US Stock', 'LQD', 'adjusted volume']
# ['US Stock', 'LYB', 'adjusted volume']
# ['US Stock', 'MBB', 'adjusted volume']
# ['US Stock', 'MPC', 'adjusted volume']
# ['US Stock', 'MS', 'adjusted volume']
# ['US Stock', 'NEM', 'adjusted volume']
# ['US Stock', 'NUE', 'adjusted volume']
# ['US Stock', 'NUGT', 'adjusted volume']
# ['US Stock', 'OIH', 'adjusted volume']
# ['US Stock', 'OKE', 'adjusted volume']
# ['US Stock', 'OXY', 'adjusted volume']
# ['US Stock', 'PAAS', 'adjusted volume']
# ['US Stock', 'RIO', 'adjusted volume']
# ['US Stock', 'RSP', 'adjusted volume']
# ['US Stock', 'RY', 'adjusted volume']
# ['US Stock', 'SCCO', 'adjusted volume']
# ['US Stock', 'SHEL', 'adjusted volume']
# ['US Stock', 'SHY', 'adjusted volume']
# ['US Stock', 'SLB', 'adjusted volume']
# ['US Stock', 'SLV', 'adjusted volume']
# ['US Stock', 'SPIB', 'adjusted volume']
# ['US Stock', 'SPTL', 'adjusted volume']
# ['US Stock', 'SPYV', 'adjusted volume']
# ['US Stock', 'STLD', 'adjusted volume']
# ['US Stock', 'TD', 'adjusted volume']
# ['US Stock', 'TECK', 'adjusted volume']
# ['US Stock', 'TIP', 'adjusted volume']
# ['US Stock', 'TRGP', 'adjusted volume']
# ['US Stock', 'URA', 'adjusted volume']
# ['US Stock', 'VALE', 'adjusted volume']
# ['US Stock', 'VCIT', 'adjusted volume']
# ['US Stock', 'VCSH', 'adjusted volume']
# ['US Stock', 'VEA', 'adjusted volume']
# ['US Stock', 'VGIT', 'adjusted volume']
# ['US Stock', 'VGK', 'adjusted volume']
# ['US Stock', 'VGLT', 'adjusted volume']
# ['US Stock', 'VGSH', 'adjusted volume']
# ['US Stock', 'VT', 'adjusted volume']
# ['US Stock', 'VTV', 'adjusted volume']
# ['US Stock', 'VWO', 'adjusted volume']
# ['US Stock', 'VXUS', 'adjusted volume']
# ['US Stock', 'VYM', 'adjusted volume']
# ['US Stock', 'WMB', 'adjusted volume']
# ['US Stock', 'WPM', 'adjusted volume']
# ['US Stock', 'X', 'adjusted volume']
# ['US Stock', 'XLB', 'adjusted volume']
# ['US Stock', 'XLE', 'adjusted volume']
# ['US Stock', 'XOM', 'adjusted volume']
# ['US Stock', 'YINN', 'adjusted volume']
# ['FX', 'AUDJPY']
# ['FX', 'AUDUSD']
# ['FX', 'CADJPY']
# ['FX', 'CHFJPY']
# ['FX', 'EURAUD']
# ['FX', 'EURGBP']
# ['FX', 'EURJPY']
# ['FX', 'EURUSD']
# ['FX', 'GBPAUD']
# ['FX', 'GBPJPY']
# ['FX', 'GBPUSD']
# ['FX', 'NZDJPY']
# ['FX', 'NZDUSD']
# ['FX', 'USDCHF']
# ['FX', 'USDJPY']
# ['FX', 'ZARJPY']
# ['FX', 'ZARUSD']
# ['FX', 'NOKUSD']
# ['FX', 'NOKEUR']
# ['FX', 'CADUSD']
# ['FX', 'AUDNZD']
# ['FX', 'EURCHF']
# ['FX', 'EURCAD']
# ['FX', 'AUDCAD']
# ['FX', 'GBPCHF']
# ['FX', 'EURNZD']
# ['FX', 'AUDCHF']
# ['FX', 'GBPNZD']
# ['FX', 'GBPCAD']
# ['FX', 'CADCHF']
# ['FX', 'NZDCAD']
# ['FX', 'NZDCHF']
# ['FX', 'ZAREUR']
# ['FX', 'NOKGBP']
# ['FX', 'NOKCHF']
# ['FX', 'ZARCHF']
# ['FX', 'NOKJPY']
# ['FX', 'ZARGBP']

# %%
columnid = list(range(1,len(train_names)+1))
column = list(train_data.columns)
category = [x[0] if len(x) > 0 else "" for x in train_names]

Ticker = [
    "_".join(x[1:len(x)-1]) if len(x) > 2 else "" 
    for x in train_names
]
Type = [x[-1] if len(x) > 0 else "" for x in train_names]

train_info = pd.DataFrame({
    "Column_Id": columnid,
    "Column": column,
    "Category": category,
    "Ticker": Ticker,
    "Type": Type
})

train_info["Ticker"] = train_info.apply(
    lambda row: row["Type"] if row["Ticker"] == "" else row["Ticker"], axis=1

)

print(train_info)
# Out:
#      Column_Id        Column Category  Ticker    Type
# 0            1       date_id     date      id      id
# 1            2  LME_AH_Close      LME      AH   Close
# 2            3  LME_CA_Close      LME      CA   Close
# 3            4  LME_PB_Close      LME      PB   Close
# 4            5  LME_ZS_Close      LME      ZS   Close
# ..         ...           ...      ...     ...     ...
# 553        554     FX_NOKGBP       FX  NOKGBP  NOKGBP
# 554        555     FX_NOKCHF       FX  NOKCHF  NOKCHF
# 555        556     FX_ZARCHF       FX  ZARCHF  ZARCHF
# 556        557     FX_NOKJPY       FX  NOKJPY  NOKJPY
# 557        558     FX_ZARGBP       FX  ZARGBP  ZARGBP
#
# [558 rows x 5 columns]

# %%
subset = train_info.iloc[1:,:]

summary = (
    subset.groupby("Category")
    .agg(
        column_count = ("Column", "count"),
        ticker_count = ("Ticker", lambda x: x.nunique())
        ).reset_index()
)

print(summary)
# Out:
#    Category  column_count  ticker_count
# 0        FX            38            38
# 1       JPX            40             6
# 2       LME             4             4
# 3  US Stock           475            95

# %%
lme_info = train_info[train_info["Category"] == "LME"]
lme_info
# Out:
#    Column_Id        Column Category Ticker   Type
# 1          2  LME_AH_Close      LME     AH  Close
# 2          3  LME_CA_Close      LME     CA  Close
# 3          4  LME_PB_Close      LME     PB  Close
# 4          5  LME_ZS_Close      LME     ZS  Close

# %%
lme_long = train_data.iloc[:,:5]
lme_long.columns = ["date_id", "Alminium", "Copper", "Lead", "Zinc"]
lme_long = lme_long.melt(
    id_vars="date_id",
    var_name = "Metal",
    value_name = "Price"
)

plt.figure(figsize=(16,6))
for metal in lme_long["Metal"].unique():
    metal_data = lme_long[lme_long["Metal"] == metal]
    plt.plot(metal_data["date_id"], metal_data["Price"], label =metal)

plt.xlabel("Data(data_id)")
plt.ylabel("Price")
plt.title("Lme : closing price of metal")
plt.legend(title = "Metal")
plt.grid()
plt.show()

# %%
jpx_info = train_info[ (train_info["Category"] == "JPX") & (train_info["Type"] == "Close")]
jpx_info
# Out:
#     Column_Id                               Column Category  \
# 23         24          JPX_Gold_Mini_Futures_Close      JPX
# 24         25  JPX_Gold_Rolling-Spot_Futures_Close      JPX
# 25         26      JPX_Gold_Standard_Futures_Close      JPX
# 26         27      JPX_Platinum_Mini_Futures_Close      JPX
# 27         28  JPX_Platinum_Standard_Futures_Close      JPX
# 28         29        JPX_RSS3_Rubber_Futures_Close      JPX
#
#                        Ticker   Type
# 23          Gold_Mini_Futures  Close
# 24  Gold_Rolling-Spot_Futures  Close
# 25      Gold_Standard_Futures  Close
# 26      Platinum_Mini_Futures  Close
# 27  Platinum_Standard_Futures  Close
# 28        RSS3_Rubber_Futures  Close

# %%
jpx_iinfo = jpx_info[jpx_info["Type"] == "Close"]

# %%
colums =[0] + jpx_iinfo["Column_Id"].tolist()
jpx_long = train_data.iloc[:,colums].copy()

jpx_long.columns = [ "date_id", "Gold Mini", "Gold Rolling Spot", "Gold Standard",
    "Platinum Mini", "Platinum Standard", "RSS3 Rubber"]

jpx_long = jpx_long.melt(
    id_vars= "date_id",
    value_name="Price",
    var_name="Futures"
)

futures_list = jpx_long["Futures"].unique()
ncol = 3 
nrow = (len(futures_list)+ ncol -1) //ncol

fig , axs = plt.subplots(nrow , ncol, figsize= (16,6),sharex = True , sharey = True )
axs = axs.flatten()

for i,future in enumerate(futures_list):
    df = jpx_long[jpx_long["Futures"] == future]
    axs[i].plot(df["date_id"], df["Price"] , color = "tab:blue")
    axs[i].set_title(future)
    axs[i].grid()

for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])


fig.suptitle("Japani", fontsize=14)
fig.text(0.5, 0.04, "Date (date_id)", ha='center')
fig.text(0.04, 0.5, "Price", va='center', rotation='vertical')
plt.tight_layout(rect=[0.03, 0.03, 1, 0.95])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 22
#      20 for i,future in enumerate(futures_list):
#      21     df = jpx_long[jpx_long["Futures"] == future]
# ---> 22     axs[i].plot(df["date_id"], df["Price"] , color = "tab:blue")
#      23     axs[i].set_title(future)
#      24     axs[i].grid()
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:491, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     489     axes.xaxis.update_units(x)
#     490 if axes.yaxis is not None:
# --> 491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
#     494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axis.py:1759, in Axis.update_units(self, data)
#    1756     self.set_units(default)
#    1758 elif neednew:
# -> 1759     self._update_axisinfo()
#    1760 self.stale = True
#    1761 return True
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axis.py:1795, in Axis._update_axisinfo(self)
#    1792     self.set_label_text(info.label)
#    1793     self.isDefault_label = True
# -> 1795 self.set_default_intervals()
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axis.py:2802, in YAxis.set_default_intervals(self)
#    2797 def set_default_intervals(self):
#    2798     # docstring inherited
#    2799     # only change view if dataLim has not changed and user has
#    2800     # not changed the view:
#    2801     if (not self.axes.dataLim.mutatedy() and
# -> 2802             not self.axes.viewLim.mutatedy()):
#    2803         if self._converter is not None:
#    2804             info = self._converter.axisinfo(self.units, self)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:904, in _AxesBase.viewLim(self)
#     901 @property
#     902 def viewLim(self):
#     903     """The view limits as `.Bbox` in data coordinates."""
# --> 904     self._unstale_viewLim()
#     905     return self._viewLim
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:898, in _AxesBase._unstale_viewLim(self)
#     896     for ax in self._shared_axes[name].get_siblings(self):
#     897         ax._stale_viewlims[name] = False
# --> 898 self.autoscale_view(**{f"scale{name}": scale
#     899                        for name, scale in need_scale.items()})
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:3086, in _AxesBase.autoscale_view(self, tight, scalex, scaley)
#    3081     # End of definition of internal function 'handle_single_axis'.
#    3083 handle_single_axis(
#    3084     scalex, self._shared_axes["x"], 'x', self.xaxis, self._xmargin,
#    3085     x_stickies, self.set_xbound)
# -> 3086 handle_single_axis(
#    3087     scaley, self._shared_axes["y"], 'y', self.yaxis, self._ymargin,
#    3088     y_stickies, self.set_ybound)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:3080, in _AxesBase.autoscale_view.<locals>.handle_single_axis(scale, shared_axes, name, axis, margin, stickies, set_bound)
#    3078 if not self._tight:
#    3079     x0, x1 = locator.view_limits(x0, x1)
# -> 3080 set_bound(x0, x1)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:3960, in _AxesBase.set_ybound(self, lower, upper)
#    3957 if upper is None:
#    3958     upper = old_upper
# -> 3960 self.set_ylim(sorted((lower, upper),
#    3961                      reverse=bool(self.yaxis_inverted())),
#    3962               auto=None)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:4062, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4060         raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4061     top = ymax
# -> 4062 return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axis.py:1261, in Axis._set_lim(self, v0, v1, emit, auto)
#    1259 if other is self.axes:
#    1260     continue
# -> 1261 other._axis_map[name]._set_lim(v0, v1, emit=False, auto=auto)
#    1262 if emit:
#    1263     other.callbacks.process(f"{name}lim_changed", other)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axis.py:1249, in Axis._set_lim(self, v0, v1, emit, auto)
#    1246 v0, v1 = self.limit_range_for_scale(v0, v1)
#    1247 v0, v1 = sorted([v0, v1], reverse=bool(reverse))
# -> 1249 self.set_view_interval(v0, v1, ignore=True)
#    1250 # Mark viewlims as no longer stale without triggering an autoscale.
#    1251 for ax in self._get_shared_axes():
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axis.py:2352, in _make_getset_interval.<locals>.setter(self, vmin, vmax, ignore)
#    2349 def setter(self, vmin, vmax, ignore=False):
#    2350     # docstring inherited.
#    2351     if ignore:
# -> 2352         setattr(getattr(self.axes, lim_name), attr_name, (vmin, vmax))
#    2353     else:
#    2354         oldmin, oldmax = getter(self)
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:904, in _AxesBase.viewLim(self)
#     901 @property
#     902 def viewLim(self):
#     903     """The view limits as `.Bbox` in data coordinates."""
# --> 904     self._unstale_viewLim()
#     905     return self._viewLim
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:890, in _AxesBase._unstale_viewLim(self)
#     887 def _unstale_viewLim(self):
#     888     # We should arrange to store this information once per share-group
#     889     # instead of on every axis.
# --> 890     need_scale = {
#     891         name: any(ax._stale_viewlims[name]
#     892                   for ax in self._shared_axes[name].get_siblings(self))
#     893         for name in self._axis_names}
#     894     if any(need_scale.values()):
#     895         for name in need_scale:
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/axes/_base.py:892, in <dictcomp>(.0)
#     887 def _unstale_viewLim(self):
#     888     # We should arrange to store this information once per share-group
#     889     # instead of on every axis.
#     890     need_scale = {
#     891         name: any(ax._stale_viewlims[name]
# --> 892                   for ax in self._shared_axes[name].get_siblings(self))
#     893         for name in self._axis_names}
#     894     if any(need_scale.values()):
#     895         for name in need_scale:
#
# File ~/Documents/DC-1/FIN-ML/dc/lib/python3.11/site-packages/matplotlib/cbook.py:874, in Grouper.get_siblings(self, a)
#     872 """Return all of the items joined with *a*, including itself."""
#     873 siblings = self._mapping.get(a, [a])
# --> 874 return sorted(siblings, key=self._ordering.get)
#
# KeyboardInterrupt:

# %%
us_info = train_info[train_info["Category"] == "US Stock" & train_info["Type"] == "adjusted close"]
us_tkr = us_info["Ticker"].tolist()

# %%
colums =[0] + jpx_iinfo["Column_Id"].tolist()
jpx_long = train_data.iloc[:,colums].copy()

jpx_long.columns = [ "date_id", "Gold Mini", "Gold Rolling Spot", "Gold Standard",
    "Platinum Mini", "Platinum Standard", "RSS3 Rubber"]

jpx_long = jpx_long.melt(
    id_vars= "date_id",
    value_name="Futures",
    var_name="Price"
)

futures_list = jpx_long["Futures"].unique()
ncol = 3 
nrow = (len(futures_list)+ ncol -1) //ncol

fig , axs = plt.subplots(nrow , ncol, figsize= (16,6),sharex = True , sharey = True )
axs = axs.flatten()

for i,future in enumerate(futures_list):
    df = jpx_long[jpx_long["Futures"] == future]
    axs[i].plot(df["date_id"], df["Price"] , color = "tab:blue")
    axs[i].set_title(future)
    axs[i].grid()

for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])


fig.suptitle("Japani", fontsize=14)
fig.text(0.5, 0.04, "Date (date_id)", ha='center')
fig.text(0.04, 0.5, "Price", va='center', rotation='vertical')
plt.tight_layout(rect=[0.03, 0.03, 1, 0.95])
plt.show()
